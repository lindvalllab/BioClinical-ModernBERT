# %%
import os
import glob
import re
import argparse
import pandas as pd
import numpy as np

# %%
results_path = "/home/ubuntu/Bio_Clinical_MBERT/scripts/outputs/HOC"

# %%
def parse_filename(filename):
    """
    Extract hyperparameters from the filename.
    Expected format: lr=<lr>_wd=<wd>_epochs=<epochs>_seed=<seed>_effective_batch_size=<effective_bs>.txt
    """
    pattern = r"lr=([^_]+)_wd=([^_]+)_epochs=([^_]+)_seed=([^_]+)_effective_batch_size=([^\.]+)"
    match = re.search(pattern, filename)
    if match:
        lr, wd, epochs, seed, effective_bs = match.groups()
        return {
            "lr": float(lr),
            "wd": float(wd),
            "epochs": int(epochs),
            "seed": int(seed),
            "effective_batch_size": int(effective_bs)
        }
    else:
        return None

def parse_log_file(filepath):
    """
    Parse the log file content, which is assumed to contain lines of the form 'Key: Value'.
    
    This function ignores lines with keys in the ignore list so that the DataFrame doesn't pick up
    headers or unwanted entries.
    """
    ignore_keys = {"test evaluation results", "epoch", "seed", "effective batch size", "eval_samples_per_second", "eval_steps_per_second", "eval_loss"}
    data = {}
    with open(filepath, 'r') as f:
        lines = f.readlines()
    
    for line in lines:
        line = line.strip()
        # Skip lines that are empty or do not contain a colon.
        if not line or ":" not in line:
            continue
        key, value = line.split(":", 1)
        key = key.strip()
        # If the lowercase key is in the ignore list, skip it.
        if key.lower() in ignore_keys:
            continue
        value = value.strip()
        # If the value is an empty string, set it to np.nan.
        if value == "":
            data[key] = np.nan
        else:
            # Try to convert to a float if possible.
            try:
                # If value contains a decimal point then convert to float, otherwise try int.
                if "." in value:
                    data[key] = float(value)
                else:
                    data[key] = int(value)
            except ValueError:
                data[key] = value  # keep as string if conversion fails
    return data

# %%
records = []

# Recursively find all .txt files in the directory.
filepaths = glob.glob(os.path.join(results_path, "**", "*.txt"), recursive=True)
if not filepaths:
    print(f"No log files found in {results_path}")

for filepath in filepaths:
    filename = os.path.basename(filepath)
    # Assume that the model name is the immediate parent folder.
    model = os.path.basename(os.path.dirname(filepath))
    
    params = parse_filename(filename)
    if params is None:
        print(f"Filename {filename} does not match the expected pattern. Skipping file.")
        continue
    
    log_data = parse_log_file(filepath)
    
    # Combine the data from the filename, file content, and model name.
    record = {
        "Model": model,
        **params,  # Contains keys: lr, wd, epochs, seed, effective_batch_size
    }
    record.update(log_data)
    records.append(record)

# Create a DataFrame from the records.
df = pd.DataFrame(records)
print("Individual results:")
print(df.head(), "\n")

# Group on Model, lr, wd, and effective_batch_size.
group_cols = ["Model", "lr", "wd", "effective_batch_size"]
ignore_cols = set(group_cols + ["seed", "epochs"])
metric_cols = [col for col in df.columns if col not in ignore_cols]

# Convert each metric column to numeric (coercing errors to NaN).
for col in metric_cols:
    df[col] = pd.to_numeric(df[col], errors="coerce")

# Define aggregation: for each metric, compute mean, median, min, and max.
agg_funcs = {col: ["mean", "median", "min", "max"] for col in metric_cols}
grouped = df.groupby(group_cols).agg(agg_funcs)

# Flatten the multi-level column index.
grouped.columns = ["_".join(col).strip() for col in grouped.columns.values]
grouped = grouped.reset_index()

for col in grouped.columns:
    if "f1" in col.lower():
        grouped[col] = (grouped[col] * 100).round(1)


print("Aggregated results over seeds:")
print(grouped.head())

# Optionally, save the aggregated DataFrame to CSV.
output_csv = os.path.join(results_path, "aggregated_results.csv")
grouped.to_csv(output_csv, index=False)
print(f"\nAggregated results saved to {output_csv}")
# Out:
# Individual results:
#              Model       lr       wd  epochs  seed  effective_batch_size  \
# 0  ModernBERT-base  0.00002  0.00001       5    44                    16
# 1  ModernBERT-base  0.00002  0.00001       5    45                    16
# 2  ModernBERT-base  0.00005  0.00001       5    42                    16
# 3  ModernBERT-base  0.00002  0.00001       5    43                    16
# 4  ModernBERT-base  0.00005  0.00001       5    46                    16
#
#    eval_weighted_f1  eval_micro_f1  eval_runtime  Training duration (seconds)  \
# 0          0.645375       0.657933       54.8963                      1290.60
# 1          0.628594       0.634454       56.0935                      1287.29
# 2          0.665773       0.669661       50.9906                      1275.34
# 3          0.667644       0.672373       55.4254                      1289.49
# 4          0.660877       0.663371       54.1044                      1256.63
#
#    Evaluation duration (seconds)  Best epoch selected
# 0                          54.90                  NaN
# 1                          56.10                  NaN
# 2                          50.99                  NaN
# 3                          55.43                  NaN
# 4                          54.11                  NaN
#
# Aggregated results over seeds:
#              Model       lr       wd  effective_batch_size  \
# 0  ModernBERT-base  0.00002  0.00001                    16
# 1  ModernBERT-base  0.00005  0.00001                    16
# 2     biobert-v1.1  0.00002  0.00001                    16
# 3     biobert-v1.1  0.00005  0.00001                    16
# 4     biobert-v1.1  0.00009  0.00001                    16
#
#    eval_weighted_f1_mean  eval_weighted_f1_median  eval_weighted_f1_min  \
# 0                   64.2                     63.9                  62.9
# 1                   66.5                     66.1                  65.7
# 2                   71.6                     72.2                  70.0
# 3                   71.4                     71.5                  69.7
# 4                   70.1                     70.0                  69.6
#
#    eval_weighted_f1_max  eval_micro_f1_mean  eval_micro_f1_median  ...  \
# 0                  66.8                65.0                  64.9  ...
# 1                  68.0                67.0                  67.0  ...
# 2                  73.1                72.0                  72.2  ...
# 3                  73.0                71.6                  71.6  ...
# 4                  70.4                70.3                  70.1  ...
#
#    Training duration (seconds)_min  Training duration (seconds)_max  \
# 0                          1280.38                          1291.09
# 1                          1256.63                          1285.79
# 2                          2774.45                          2779.88
# 3                          2766.15                          2779.91
# 4                          2759.77                          2779.80
#
#    Evaluation duration (seconds)_mean  Evaluation duration (seconds)_median  \
# 0                              55.524                                 55.43
# 1                              46.328                                 51.66
# 2                              44.880                                 45.03
# 3                              43.924                                 43.62
# 4                              42.382                                 42.61
#
#    Evaluation duration (seconds)_min  Evaluation duration (seconds)_max  \
# 0                              54.90                              56.10
# 1                              21.35                              54.11
# 2                              44.45                              45.34
# 3                              43.41                              45.04
# 4                              41.77                              42.65
#
#    Best epoch selected_mean  Best epoch selected_median  \
# 0                       NaN                         NaN
# 1                       NaN                         NaN
# 2                       NaN                         NaN
# 3                       NaN                         NaN
# 4                       NaN                         NaN
#
#    Best epoch selected_min  Best epoch selected_max
# 0                      NaN                      NaN
# 1                      NaN                      NaN
# 2                      NaN                      NaN
# 3                      NaN                      NaN
# 4                      NaN                      NaN
#
# [5 rows x 28 columns]
#
# Aggregated results saved to /home/ubuntu/Bio_Clinical_MBERT/scripts/outputs/HOC/aggregated_results.csv

# %%
grouped
# Out:
#                                                 Model       lr       wd  \
# 0                                     ModernBERT-base  0.00002  0.00001
# 1                                     ModernBERT-base  0.00005  0.00001
# 2                                        biobert-v1.1  0.00002  0.00001
# 3                                        biobert-v1.1  0.00005  0.00001
# 4                                        biobert-v1.1  0.00009  0.00001
# 5                                 biomed_roberta_base  0.00002  0.00001
# 6                                 biomed_roberta_base  0.00005  0.00001
# 7      modernbert_phase2_bio_1ep_decay_after_3ep_15mr  0.00002  0.00001
# 8      modernbert_phase2_bio_1ep_decay_after_3ep_15mr  0.00005  0.00001
# 9      modernbert_phase2_bio_1ep_decay_after_3ep_15mr  0.00007  0.00001
# 10     modernbert_phase2_bio_1ep_decay_after_3ep_15mr  0.00008  0.00001
# 11     modernbert_phase2_bio_1ep_decay_after_3ep_15mr  0.00009  0.00001
# 12     modernbert_phase2_bio_1ep_decay_after_3ep_15mr  0.00010  0.00001
# 13  modernbert_phase2_clinical_2ep_constant_1ep_de...  0.00002  0.00001
# 14  modernbert_phase2_clinical_2ep_constant_1ep_de...  0.00005  0.00001
# 15  modernbert_phase2_clinical_3ep_decay_after_3ep...  0.00002  0.00001
# 16  modernbert_phase2_clinical_3ep_decay_after_3ep...  0.00005  0.00001
# 17  modernbert_phase2_large_bio_1ep_decay_after_3e...  0.00002  0.00001
# 18  modernbert_phase2_large_bio_1ep_decay_after_3e...  0.00005  0.00001
# 19  modernbert_phase2_large_clinical_2ep_constant_...  0.00002  0.00001
# 20  modernbert_phase2_large_clinical_2ep_constant_...  0.00005  0.00001
# 21  modernbert_phase2_large_clinical_3ep_decay_aft...  0.00002  0.00001
# 22  modernbert_phase2_large_clinical_3ep_decay_aft...  0.00005  0.00001
#
#     effective_batch_size  eval_weighted_f1_mean  eval_weighted_f1_median  \
# 0                     16                   64.2                     63.9
# 1                     16                   66.5                     66.1
# 2                     16                   71.6                     72.2
# 3                     16                   71.4                     71.5
# 4                     16                   70.1                     70.0
# 5                     16                   71.5                     71.5
# 6                     16                   71.0                     70.9
# 7                     16                   67.9                     67.8
# 8                     16                   67.2                     67.7
# 9                     16                   68.4                     68.8
# 10                    16                   67.9                     68.0
# 11                    16                   68.9                     69.1
# 12                    16                   68.5                     68.5
# 13                    16                   66.7                     66.7
# 14                    16                   67.7                     67.6
# 15                    16                   66.6                     66.9
# 16                    16                   67.3                     67.5
# 17                    16                   69.7                     69.9
# 18                    16                   69.1                     69.2
# 19                    16                   69.4                     69.4
# 20                    16                   68.7                     68.3
# 21                    16                   68.7                     68.7
# 22                    16                   69.4                     69.2
#
#     eval_weighted_f1_min  eval_weighted_f1_max  eval_micro_f1_mean  \
# 0                   62.9                  66.8                65.0
# 1                   65.7                  68.0                67.0
# 2                   70.0                  73.1                72.0
# 3                   69.7                  73.0                71.6
# 4                   69.6                  70.4                70.3
# 5                   70.6                  72.4                71.6
# 6                   70.2                  71.7                71.0
# 7                   67.3                  68.6                68.3
# 8                   66.1                  68.1                67.8
# 9                   67.1                  69.1                68.8
# 10                  66.9                  68.6                68.5
# 11                  68.1                  69.3                69.4
# 12                  67.2                  69.5                69.0
# 13                  65.9                  67.4                67.2
# 14                  66.0                  68.9                68.3
# 15                  65.7                  67.6                67.1
# 16                  65.8                  68.0                67.8
# 17                  68.3                  70.4                70.2
# 18                  66.1                  70.7                69.4
# 19                  68.8                  70.0                70.0
# 20                  67.7                  70.5                69.3
# 21                  68.3                  69.2                69.3
# 22                  68.9                  70.5                69.7
#
#     eval_micro_f1_median  ...  Training duration (seconds)_min  \
# 0                   64.9  ...                          1280.38
# 1                   67.0  ...                          1256.63
# 2                   72.2  ...                          2774.45
# 3                   71.6  ...                          2766.15
# 4                   70.1  ...                          2759.77
# 5                   71.6  ...                          2773.51
# 6                   71.0  ...                          2778.82
# 7                   68.3  ...                          1263.84
# 8                   68.2  ...                          1264.11
# 9                   69.3  ...                          1261.41
# 10                  68.6  ...                          1259.56
# 11                  69.4  ...                          1271.15
# 12                  69.3  ...                          1264.16
# 13                  67.3  ...                          1277.85
# 14                  68.3  ...                          1260.44
# 15                  67.5  ...                          1265.74
# 16                  67.8  ...                          1264.53
# 17                  70.3  ...                          1417.93
# 18                  69.8  ...                          1435.98
# 19                  69.9  ...                          1445.83
# 20                  69.1  ...                          1444.03
# 21                  69.2  ...                          1432.56
# 22                  69.6  ...                          1446.74
#
#     Training duration (seconds)_max  Evaluation duration (seconds)_mean  \
# 0                           1291.09                              55.524
# 1                           1285.79                              46.328
# 2                           2779.88                              44.880
# 3                           2779.91                              43.924
# 4                           2779.80                              42.382
# 5                           2797.31                              41.270
# 6                           2789.62                              40.294
# 7                           1281.37                              53.924
# 8                           1277.06                              54.852
# 9                           1280.18                              54.114
# 10                          1279.90                              53.958
# 11                          1276.24                              56.126
# 12                          1276.36                              54.130
# 13                          1285.39                              54.814
# 14                          1286.53                              52.564
# 15                          1292.29                              52.994
# 16                          1287.34                              53.614
# 17                          1445.48                              43.518
# 18                          1457.76                              52.048
# 19                          1457.36                              53.902
# 20                          1465.03                              52.650
# 21                          1489.65                              47.086
# 22                          1460.14                              54.304
#
#     Evaluation duration (seconds)_median  Evaluation duration (seconds)_min  \
# 0                                  55.43                              54.90
# 1                                  51.66                              21.35
# 2                                  45.03                              44.45
# 3                                  43.62                              43.41
# 4                                  42.61                              41.77
# 5                                  41.24                              40.09
# 6                                  44.32                              33.04
# 7                                  55.29                              51.32
# 8                                  54.65                              53.45
# 9                                  55.24                              49.81
# 10                                 53.83                              52.73
# 11                                 56.65                              55.17
# 12                                 53.44                              52.38
# 13                                 55.17                              53.53
# 14                                 53.14                              47.76
# 15                                 54.44                              48.25
# 16                                 53.48                              51.46
# 17                                 47.81                              22.03
# 18                                 52.68                              48.90
# 19                                 53.36                              52.51
# 20                                 53.44                              46.89
# 21                                 50.74                              29.63
# 22                                 55.38                              48.47
#
#     Evaluation duration (seconds)_max  Best epoch selected_mean  \
# 0                               56.10                       NaN
# 1                               54.11                       NaN
# 2                               45.34                       NaN
# 3                               45.04                       NaN
# 4                               42.65                       NaN
# 5                               43.06                       NaN
# 6                               45.59                       NaN
# 7                               55.82                       NaN
# 8                               56.66                       NaN
# 9                               55.47                       NaN
# 10                              55.63                       NaN
# 11                              56.87                       NaN
# 12                              55.79                       4.8
# 13                              55.58                       NaN
# 14                              55.01                       NaN
# 15                              55.13                       NaN
# 16                              56.01                       NaN
# 17                              51.55                       NaN
# 18                              53.56                       NaN
# 19                              57.02                       NaN
# 20                              56.36                       NaN
# 21                              53.50                       NaN
# 22                              57.10                       NaN
#
#     Best epoch selected_median  Best epoch selected_min  \
# 0                          NaN                      NaN
# 1                          NaN                      NaN
# 2                          NaN                      NaN
# 3                          NaN                      NaN
# 4                          NaN                      NaN
# 5                          NaN                      NaN
# 6                          NaN                      NaN
# 7                          NaN                      NaN
# 8                          NaN                      NaN
# 9                          NaN                      NaN
# 10                         NaN                      NaN
# 11                         NaN                      NaN
# 12                         5.0                      4.0
# 13                         NaN                      NaN
# 14                         NaN                      NaN
# 15                         NaN                      NaN
# 16                         NaN                      NaN
# 17                         NaN                      NaN
# 18                         NaN                      NaN
# 19                         NaN                      NaN
# 20                         NaN                      NaN
# 21                         NaN                      NaN
# 22                         NaN                      NaN
#
#     Best epoch selected_max
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 5                       NaN
# 6                       NaN
# 7                       NaN
# 8                       NaN
# 9                       NaN
# 10                      NaN
# 11                      NaN
# 12                      5.0
# 13                      NaN
# 14                      NaN
# 15                      NaN
# 16                      NaN
# 17                      NaN
# 18                      NaN
# 19                      NaN
# 20                      NaN
# 21                      NaN
# 22                      NaN
#
# [23 rows x 28 columns]
